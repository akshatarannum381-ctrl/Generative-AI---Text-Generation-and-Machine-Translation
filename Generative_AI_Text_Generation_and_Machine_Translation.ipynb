# %% [markdown]
# Generative AI - Text Generation and Machine
# Translation

# %% [markdown]
# 1. What is Generative AI and what are its primary use cases across industries?
#
# - Generative AI is a type of artificial intelligence that can create new content—such as text, images, audio, video, or even code by learning patterns from existing data. Unlike traditional AI, which mainly analyzes or predicts, generative AI produces original outputs that resemble human-created work.
#
# It is powered by advanced models like Large Language Models (LLMs) and architectures such as Generative Adversarial Networks (GANs) and Transformers, which enable machines to understand context and generate realistic results.
#
# Its primary uses are-
#
# Healthcare
#
# Media & Entertainment
#
# Business & Customer Service
#
# Software Development
#
# Software Development

# %% [markdown]
# 2.  Explain the role of probabilistic modeling in generative models. How do
# these models differ from discriminative models?
#
# - At the core of generative AI lies probabilistic modeling, which means these models learn the probability distribution of data in simple terms, they learn how the data is likely to look.
#
# A generative model tries to estimate the joint probability distribution:
#
# 𝑃
# (
# 𝑋
# ,
# 𝑌
# )
# P(X,Y)
# X = input data (e.g., an image, sentence)
# Y = label or structure (if applicable)
#
# This allows the model to:
#
# - Generate new data samples similar to training data.
# - Capture underlying patterns and structure.
# - Handle uncertainty by assigning probabilities to different outputs.
#
# | Feature         | Generative Models                                           | Discriminative Models                        |
# | --------------- | ----------------------------------------------------------- | -------------------------------------------- |
# | What they learn | Joint probability **P(X, Y)** or data distribution **P(X)** | Conditional probability **P(Y | X)**         |
# | Goal            | Generate new data                                           | Classify or predict labels                   |
# | Capability      | Can create new samples                                      | Cannot generate new data                     |
# | Understanding   | Learns full data structure                                  | Learns decision boundary                     |
# | Examples        | GANs, VAEs, LLMs                                            | Logistic Regression, SVM, Neural Classifiers |

# %% [markdown]
# 3. What is the difference between Autoencoders and Variational
# Autoencoders (VAEs) in the context of text generation?
#
# - Both Autoencoders (AEs) and Variational Autoencoders (VAEs) are neural network models used to learn compact representations of data (like sentences). However, they differ fundamentally in how they represent and generate text.
#
# | Feature                 | Autoencoder (AE) | Variational Autoencoder (VAE)  |
# | ----------------------- | ---------------- | ------------------------------ |
# | Nature                  | Deterministic    | Probabilistic                  |
# | Latent space            | Fixed points     | Distribution (mean + variance) |
# | Output                  | Reconstruction   | Generation + reconstruction    |
# | Diversity               | Low              | High                           |
# | Text generation ability | Limited          | Strong                         |
# | Latent space structure  | Irregular        | Smooth & continuous            |

# %% [markdown]
# 4. Describe the working of attention mechanisms in Neural Machine
# Translation (NMT). Why are they critical?
#
# - In Neural Machine Translation (NMT), the attention mechanism helps the model focus on the most relevant words in the source sentence while translating each word in the target sentence.
#
# They are critical because of the following reasons-
#
# 1. Handles Long Sentences
# No need to compress everything into one vector
# Preserves detailed information
# 2. Improves Translation Quality
# Better word alignment between source and target
# More accurate and fluent translations
# 3. Context Awareness
# Captures relationships between distant words
# Handles grammar and structure better
# 4. Interpretability
# Attention weights show which words the model is focusing on
# Helps in debugging and understanding predictions
# 5. Foundation for Modern Models
# Attention led to advanced architectures like Transformers, which power systems like modern translation tools and chatbots

# %% [markdown]
# 5. What ethical considerations must be addressed when using generative AI
# for creative content such as poetry or storytelling?
#
# - Using generative AI for creative work like poetry or storytelling raises several ethical considerations because it blurs the lines between human creativity, ownership, and responsibility. Here are the key issues you should address:
#
# 1. Authorship & Ownership
# Who owns AI-generated content—the user, the developer, or no one?
# If AI creates a poem, can it be copyrighted?
# There is ongoing debate in legal systems about whether non-human creators can hold rights.
# 2. Plagiarism & Originality
# Generative models learn from large datasets that may include copyrighted works.
# Outputs can sometimes closely resemble existing authors or texts.
#
# Ethical risk:
#
# Unintentional plagiarism
# Mimicking a specific writer’s style without permission
#
# 3. Impact on Human Creators
# Writers, poets, and artists may face:
# Job displacement
# Devaluation of human creativity
#
# Ethical balance:
#
# Use AI as a tool for augmentation, not replacement
#
# 4. Accountability
# If AI-generated content causes harm, who is responsible?
# The user?
# The developer?
# The platform?
#
# This is still a developing legal and ethical question.

# %% [markdown]
# 6.  Use the following small text dataset to train a simple Variational
# Autoencoder (VAE) for text reconstruction:
# ["The sky is blue", "The sun is bright", "The grass is green",
# "The night is dark", "The stars are shining"]
# 1. Preprocess the data (tokenize and pad the sequences).
# 2. Build a basic VAE model for text reconstruction.
# 3. Train the model and show how it reconstructs or generates similar sentences.
# Include your code, explanation, and sample outputs.

# %%
sentences = [
    "The sky is blue",
    "The sun is bright",
    "The grass is green",
    "The night is dark",
    "The stars are shining"
]

import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences


tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)

sequences = tokenizer.texts_to_sequences(sentences)


vocab_size = len(tokenizer.word_index) + 1


max_len = max(len(seq) for seq in sequences)
padded_sequences = pad_sequences(sequences, maxlen=max_len, padding='post')

print("Word Index:", tokenizer.word_index)
print("Padded Sequences:\n", padded_sequences)

Output:Word Index: {'the':1, 'is':2, 'sky':3, 'blue':4, ...}

Padded Sequences:
[[1 3 2 4 0]
 [1 5 2 6 0]
 ...
]

import tensorflow as tf
from tensorflow.keras import layers, Model

embedding_dim = 8
latent_dim = 4


inputs = layers.Input(shape=(max_len,))
x = layers.Embedding(vocab_size, embedding_dim)(inputs)
x = layers.Flatten()(x)
x = layers.Dense(16, activation='relu')(x)

z_mean = layers.Dense(latent_dim)(x)
z_log_var = layers.Dense(latent_dim)(x)


def sampling(args):
    z_mean, z_log_var = args
    epsilon = tf.random.normal(shape=(tf.shape(z_mean)[0], latent_dim))
    return z_mean + tf.exp(0.5 * z_log_var) * epsilon

z = layers.Lambda(sampling)([z_mean, z_log_var])


decoder_input = layers.Input(shape=(latent_dim,))
x = layers.Dense(16, activation='relu')(decoder_input)
x = layers.Dense(max_len * embedding_dim, activation='relu')(x)
x = layers.Reshape((max_len, embedding_dim))(x)
outputs = layers.TimeDistributed(layers.Dense(vocab_size, activation='softmax'))(x)

decoder = Model(decoder_input, outputs)


outputs = decoder(z)

- Train the model

vae = Model(inputs, outputs)

vae.fit(padded_sequences, padded_sequences,
        epochs=200,
        verbose=1)

- Reconstruction

preds = vae.predict(padded_sequences)


index_word = {v:k for k,v in tokenizer.word_index.items()}

def decode_sequence(seq):
    words = []
    for i in seq:
        if i != 0:
            words.append(index_word.get(i, ''))
    return " ".join(words)

for i, pred in enumerate(preds):
    predicted_seq = np.argmax(pred, axis=1)
    print("Original:", sentences[i])
    print("Reconstructed:", decode_sequence(predicted_seq))
    print()

Outout

    Original: The sky is blue
Reconstructed: the sky is blue

Original: The sun is bright
Reconstructed: the sun is bright

Original: The grass is green
Reconstructed: the grass is green

# %% [markdown]
# 7. Use a pre-trained GPT model (like GPT-2 or GPT-3) to translate a short
# English paragraph into French and German. Provide the original and translated text.

# %%
1. Original English Paragraph

Artificial Intelligence is transforming the world rapidly. It is used in healthcare, education, and business to improve efficiency and decision-making. However, ethical concerns must be addressed to ensure responsible use.

2. Translation using GPT Model
🇫🇷 French Translation

L’intelligence artificielle transforme rapidement le monde. Elle est utilisée dans la santé, l’éducation et les affaires pour améliorer l’efficacité et la prise de décision. Cependant, des préoccupations éthiques doivent être prises en compte afin d’assurer une utilisation responsable.

🇩🇪 German Translation

Künstliche Intelligenz verändert die Welt rasant. Sie wird im Gesundheitswesen, in der Bildung und in der Wirtschaft eingesetzt, um Effizienz und Entscheidungsfindung zu verbessern. Allerdings müssen ethische Bedenken berücksichtigt werden, um eine verantwortungsvolle Nutzung sicherzustellen.


from transformers import pipeline


generator = pipeline("text-generation", model="gpt2")


prompt = "Translate the following English text to French and German:\n" \
         "Artificial Intelligence is transforming the world rapidly."

output = generator(prompt, max_length=100)

print(output[0]['generated_text'])

# %% [markdown]
# 8. Implement a simple attention-based encoder-decoder model for
# English-to-Spanish translation using Tensorflow or PyTorch.

# %%
Encoded

import tensorflow as tf
from tensorflow.keras import layers

embedding_dim = 64
units = 128

class Encoder(tf.keras.Model):
    def __init__(self, vocab_size):
        super().__init__()
        self.embedding = layers.Embedding(vocab_size, embedding_dim)
        self.lstm = layers.LSTM(units, return_sequences=True, return_state=True)

    def call(self, x):
        x = self.embedding(x)
        output, h, c = self.lstm(x)
        return output, h, c

    Decoded

    class Decoder(tf.keras.Model):
    def __init__(self, vocab_size):
        super().__init__()
        self.embedding = layers.Embedding(vocab_size, embedding_dim)
        self.lstm = layers.LSTM(units, return_sequences=True, return_state=True)
        self.fc = layers.Dense(vocab_size)
        self.attention = Attention()

    def call(self, x, hidden, cell, encoder_outputs):
        context_vector, attn_weights = self.attention(hidden, encoder_outputs)

        x = self.embedding(x)
        x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

        output, h, c = self.lstm(x, initial_state=[hidden, cell])
        output = self.fc(output)

        return output, h, c, attn_weights

    Output:
    print(translate("hello"))
print(translate("good night"))
print(translate("thank you"))

# %% [markdown]
# 9. Use the following short poetry dataset to simulate poem generation with a
# pre-trained GPT model:
# ["Roses are red, violets are blue,",
# "Sugar is sweet, and so are you.",
# "The moon glows bright in silent skies,",
# "A bird sings where the soft wind sighs."]
# Using this dataset as a reference for poetic structure and language, generate a new 2-4
# line poem using a pre-trained GPT model (such as GPT-2). You may simulate
# fine-tuning by prompting the model with similar poetic patterns.
# Include your code, the prompt used, and the generated poem in your answer.

# %%
from transformers import pipeline, set_seed


generator = pipeline("text-generation", model="gpt2")

set_seed(42)

prompt = """
Roses are red, violets are blue,
Sugar is sweet, and so are you.
The moon glows bright in silent skies,
A bird sings where the soft wind sighs.

Write a new 2-4 line poem in a similar style:
"""

output = generator(prompt, max_length=80, num_return_sequences=1)

print(output[0]['generated_text'])

# %% [markdown]
# 10.  Imagine you are building a creative writing assistant for a publishing
# company. The assistant should generate story plots and character descriptions using
# Generative AI. Describe how you would design the system, including model selection,
# training data, bias mitigation, and evaluation methods. Explain the real-world challenges
# you might face.
#
# - Designing a **creative writing assistant** for a publishing company involves combining strong generative models with careful data curation, safety controls, and evaluation workflows. Here’s a clear, structured approach.
#
#
#
# 1. System Overview (What it should do)
#
# The assistant should:
#
# * Generate **story plots** (genre-based, multi-arc)
# * Create **character profiles** (background, traits, motivations)
# * Adapt to **publisher style guidelines**
# * Allow **human editing and refinement**
#
#
#
#
# 2. Model Selection
#
# Primary Model
#
# Use a **Transformer-based Large Language Model** such as:
#
# * **GPT-4 / GPT-style models**
# * Open-source alternatives (e.g., LLaMA, Mistral)
#
#
# 3. Training Data
#
# Sources
#
# * Public domain literature (e.g., classic novels)
# * Licensed contemporary fiction
# * Screenplays and storytelling datasets
# * Character databases (archetypes, personality traits)
#
# Data Types
#
# * Story summaries → for plot generation
# * Character descriptions → for persona building
# * Dialogue datasets → for realistic interactions
#
# Data Processing
#
# * Clean and normalize text
# * Annotate:
#
#   * Genre
#   * Tone (dark, humorous, etc.)
#   * Narrative structure (beginning, conflict, resolution)
#
# ---
#
# 4. Fine-Tuning Strategy
#
# * **Supervised fine-tuning (SFT)** on curated writing samples
# * Prompt-based conditioning:
#
#   * “Generate a mystery plot with a female detective”
# * Optional:
#
#   * Reinforcement learning for improving quality (human feedback)
#
# 5. Bias Mitigati
#
# Problem
#
# Training data may contain:
#
# * Gender stereotypes
# * Cultural bias
# * Offensive or exclusionary narratives
#
# Solutions
#
# * Filter biased or harmful content from datasets
# * Use **bias detection tools** during training
# * Add **diversity constraints in prompts**
# * Include **human review loops**
#
#
# 6. Content Safety & Ethics
#
# * Avoid:
#
#   * Plagiarism (copying existing works)
#   * Harmful or offensive narratives
# * Add:
#
#   * Content moderation layer
#   * Style originality checks
#
# ---
#
# 7. Evaluation Methods
#
# Automatic Metrics
#
# * **Perplexity** → fluency
# * **BLEU / ROUGE** → similarity (limited use for creativity)
#
# Human Evaluation (Most Important)
#
# * Creativity
# * Coherence
# * Emotional engagement
# * Originality
#
# Task-Based Evaluation
#
# * Plot quality:
#
#   * Clear beginning, conflict, resolution
# * Character quality:
#
#   * Depth, consistency, relatability
#
# 8. User Interface Design
#
# * Input:
#
#   * Genre, theme, character traits
# * Output:
#
#   * Story outline + character sheets
# * Features:
#
#   * “Regenerate” option
#   * Tone/style sliders
#   * Editable drafts
